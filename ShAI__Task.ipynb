# %% [markdown]
# # Importing needed libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # - first, i loaded the dataset and printed it

# %%
data = pd.read_csv("Salaries.csv")
data
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %% [markdown]
# - Exploring our dataset, first i printed the shape of the dataset and i found that there is 13 columns and 148654 rows.
# - After that, i got informations from the dataset such as the type of each column and i found that i have 3 columns of type       object , 2 columns of type integer and 8 columns of type float.
# - Also, i printed the statistic informations of the dataset such as the max , min std, mean, median...etc of each column in the   dataset
# -  the range of salaries is between the max and min
# - also i noticed that there is a negative numbers in the salaries column and this is not true and these negative number must be   removed i think this negative numbers will not add anything to my analysis as if i work to analyis the number that the company   give to its employees , i will not consider the number i got from the employee.

# %%
data.columns
data.shape
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB
#                   Id        BasePay    OvertimePay       OtherPay  \
# ...

# %% [markdown]
# -  here i checked the null values of each column and i found that the data need to be more clean by removing all this null          values, also i noticed that the "Notes" column has nothing but null values so i will remove it by the way and only the          columns : "Id", "EmployeeName" , "JobTitle" , "TotalPay" , "TotalPayBenefits" , "Year" , "Agency" has no null values so these    columns are clean already.

# %%
data.isnull()
# Out:
#            Id  EmployeeName  JobTitle  BasePay  OvertimePay  OtherPay  \
# 0       False         False     False    False        False     False
# 1       False         False     False    False        False     False
# 2       False         False     False    False        False     False
# 3       False         False     False    False        False     False
# 4       False         False     False    False        False     False
# ...       ...           ...       ...      ...          ...       ...
# 148649  False         False     False    False        False     False
# 148650  False         False     False     True         True      True
# 148651  False         False     False     True         True      True
# 148652  False         False     False     True         True      True
# 148653  False         False     False    False        False     False
#
#         Benefits  TotalPay  TotalPayBenefits   Year  Notes  Agency  Status
# ...

# %% [markdown]
# - Data Cleaning, i handled the missing values by replacing them by the mean of each column and i used this mehod as it is the     common methos used for handling it
# - i used this method and i know that the data contains non integer values , but these non-integer values columns has no null       values in it ,so this will not affect them.

# %%
data = data.fillna(data.mean())
# Out:
# C:\Users\walaa\AppData\Local\Temp\ipykernel_10484\476127175.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data = data.fillna(data.mean())

# %% [markdown]
# - Creating histograms to represent the distribution of salaries

# %%
data["BasePay"].hist()
# Out:
# <Axes: >

# %%
data["OvertimePay"].hist()
# Out:
# <Axes: >

# %%
data["OtherPay"].hist()
# Out:
# <Axes: >

# %%
data["TotalPay"].hist()
# Out:
# <Axes: >

# %%
data["TotalPayBenefits"].hist()
# Out:
# <Axes: >

# %%
data["JobTitle"].astype("string")
values = data["JobTitle"]

# %%
# for i in data["TotalPay"]:
#     if i > 0:
#         data["TotalPay"] = i
# plt.pie(data["TotalPay"], labels=values)
# Out:
# ([<matplotlib.patches.Wedge at 0x215c62934d0>,
# ...
#   ...],
#  [Text(1.0999999997543544, 2.324694932702015e-05, 'GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY'),
#   Text(1.0999999977891883, 6.974084793952943e-05, 'CAPTAIN III (POLICE DEPARTMENT)'),
#   Text(1.0999999938588563, 0.00011623474642744568, 'CAPTAIN III (POLICE DEPARTMENT)'),
#   Text(1.0999999879633582, 0.00016272864470770685, 'WIRE ROPE CABLE MAINTENANCE MECHANIC'),
#   Text(1.0999999801026943, 0.00020922254269725095, 'DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)'),
#   Text(1.0999999702768644, 0.00025571644031301594, 'ASSISTANT DEPUTY CHIEF II'),
#   Text(1.0999999584858684, 0.00030221033747193974, 'BATTALION CHIEF, (FIRE DEPARTMENT)'),
#   Text(1.0999999447297064, 0.00034870423409096035, 'DEPUTY DIRECTOR OF INVESTMENTS'),
#   Text(1.0999999290083786, 0.0003951981300870159, 'BATTALION CHIEF, (FIRE DEPARTMENT)'),
#   Text(1.099999911321885, 0.00044169202537704415, 'CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)'),
# ...
# ...

# %% [markdown]
# - Grouping the dataset into different columns to extract insights

# %%
data["BasePay"].describe()
data["OvertimePay"].describe()
data["OtherPay"].describe()
data["TotalPay"].describe()
data["TotalPayBenefits"].describe()

# %% [markdown]
# - Printing the correlation between two columns

# %%
corr = data["BasePay"].corr(data["TotalPay"])

# %% [markdown]
# - from the above analysis i found that there is a high correlation between the two columns and that the range of salaries is       between the min and max that printed above
